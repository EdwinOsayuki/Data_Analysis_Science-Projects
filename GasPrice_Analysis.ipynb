# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gas = pd.read_csv('gas_prices.csv')
gas.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
gas.shape
# Out:
# (19, 11)

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         19 non-null     int64
#  1   Australia    18 non-null     float64
#  2   Canada       19 non-null     float64
#  3   France       19 non-null     float64
#  4   Germany      19 non-null     float64
#  5   Italy        19 non-null     float64
#  6   Japan        19 non-null     float64
#  7   Mexico       19 non-null     float64
#  8   South Korea  19 non-null     float64
#  9   UK           19 non-null     float64
#  10  USA          19 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 1.8 KB

# %%
plt.figure(figsize=(8,6))

plt.grid()

plt.title('Gas Sales for different Countries (in USD)')
plt.plot(gas.Year, gas.USA, 'b.-', label='USA')
plt.plot(gas.Year, gas.Canada, 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='South Korea')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Australia')



plt.xticks(gas.Year[::3])

plt.xlabel('Year')
plt.ylabel('Price in USD')

plt.legend()

plt.show()
# Out:
# Australia
# Canada
# France
# Germany
# Italy
# Japan
# Mexico
# South Korea
# UK
# USA

# %%
import matplotlib

matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (22, 10)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
fig, axs = plt.subplots(5, 2, figsize=(20, 30))
sns.set_style('darkgrid')

axs[0,0].set_title('Gas Sales for USA (in USD)')
axs[0,0].plot(gas['USA'], 'o-b')
plt.plot(gas.Year, gas.USA, 'b.-')
g = sns.barplot(gas.Year, y='USA', data=gas, ax=axs[0,0])
g.set_xticklabels(g.get_xticklabels(), rotation=75)


axs[0,1].set_title('Gas Sales for Canada (in USD)')
axs[0,1].plot(gas['USA'], 'o-g')
plt.plot(gas.Year, gas.Canada, 'b.-')
g = sns.barplot(gas.Year, y='Canada', data=gas, ax=axs[0,1])
g.set_xticklabels(g.get_xticklabels(), rotation=75)


axs[1,0].set_title('Gas Sales for South Korea (in USD)')
axs[1,0].plot(gas['South Korea'], 'o-g')
plt.plot(gas.Year, gas['South Korea'], 'b.-')
g = sns.barplot(gas.Year, y='South Korea', data=gas, ax=axs[1,0])
g.set_xticklabels(g.get_xticklabels(), rotation=75)

axs[1,1].set_title('Gas Sales for Mexico (in USD)')
axs[1,1].plot(gas['Mexico'], 'o-g')
plt.plot(gas.Year, gas['Mexico'], 'b.-')
g = sns.barplot(gas.Year, y='Mexico', data=gas, ax=axs[1,1])
g.set_xticklabels(g.get_xticklabels(), rotation=75)

axs[2,0].set_title('Gas Sales for France (in USD)')
axs[2,0].plot(gas['France'], 'o-g')
plt.plot(gas.Year, gas['France'], 'b.-')
g = sns.barplot(gas.Year, y='France', data=gas, ax=axs[2,0])
g.set_xticklabels(g.get_xticklabels(), rotation=75)

axs[2,1].set_title('Gas Sales for Australia (in USD)')
axs[2,1].plot(gas['Australia'], 'o-g')
plt.plot(gas.Year, gas['Australia'], 'b.-')
g = sns.barplot(gas.Year, y='Australia', data=gas, ax=axs[2,1])
g.set_xticklabels(g.get_xticklabels(), rotation=75)

axs[3,0].set_title('Gas Sales for Germany (in USD)')
axs[3,0].plot(gas['Germany'], 'o-g')
plt.plot(gas.Year, gas['Germany'], 'b.-')
g = sns.barplot(gas.Year, y='Germany', data=gas, ax=axs[3,0])
g.set_xticklabels(g.get_xticklabels(), rotation=75)

axs[3,1].set_title('Gas Sales for Italy (in USD)')
axs[3,1].plot(gas['Italy'], 'o-g')
plt.plot(gas.Year, gas['Italy'], 'b.-')
g = sns.barplot(gas.Year, y='Italy', data=gas, ax=axs[3,1])
g.set_xticklabels(g.get_xticklabels(), rotation=75)

axs[4,0].set_title('Gas Sales for Japan (in USD)')
axs[4,0].plot(gas['Japan'], 'o-g')
plt.plot(gas.Year, gas['Japan'], 'b.-')
g = sns.barplot(gas.Year, y='Japan', data=gas, ax=axs[4,0])
g.set_xticklabels(g.get_xticklabels(), rotation=75)

axs[4,1].set_title('Gas Sales for UK (in USD)')
axs[4,1].plot(gas['UK'], 'o-g')
plt.plot(gas.Year, gas['UK'], 'b.-')
g = sns.barplot(gas.Year, y='UK', data=gas, ax=axs[4,1])
g.set_xticklabels(g.get_xticklabels(), rotation=75)

plt.tight_layout(pad=4);

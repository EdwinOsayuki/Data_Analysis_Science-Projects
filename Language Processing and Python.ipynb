# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %% [markdown]
# # Searching Text
# Here, we will search the text 'monstrous' from the Moby Dick text. There are many ways to examine the context of a text apart from simply reading it. A concordance view shows us every occurrence of a given word, together with some context. Here we look up the word monstrous in Moby Dick by entering text1 followed by a period, then the term concordance, and then placing "monstrous" in parentheses.
#
# A concordance permits us to see words in context.

# %%
text1.concordance ('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text2.concordance ('affection')
# Out:
# Displaying 25 of 79 matches:
# , however , and , as a mark of his affection for the three girls , he left them
# t . It was very well known that no affection was ever supposed to exist between
# deration of politeness or maternal affection on the side of the former , the tw
# d the suspicion -- the hope of his affection for me may warrant , without impru
# hich forbade the indulgence of his affection . She knew that his mother neither
# rd she gave one with still greater affection . Though her late conversation wit
#  can never hope to feel or inspire affection again , and if her home be uncomfo
# m of the sense , elegance , mutual affection , and domestic comfort of the fami
# , and which recommended him to her affection beyond every thing else . His soci
# ween the parties might forward the affection of Mr . Willoughby , an equally st
#  the most pointed assurance of her affection . Elinor could not be surprised at
# ...

# %%
text3.concordance ('lived')
# Out:
# Displaying 25 of 38 matches:
# ay when they were created . And Adam lived an hundred and thirty years , and be
# ughters : And all the days that Adam lived were nine hundred and thirty yea and
# nd thirty yea and he died . And Seth lived an hundred and five years , and bega
# ve years , and begat Enos : And Seth lived after he begat Enos eight hundred an
# welve years : and he died . And Enos lived ninety years , and begat Cainan : An
#  years , and begat Cainan : And Enos lived after he begat Cainan eight hundred
# ive years : and he died . And Cainan lived seventy years and begat Mahalaleel :
# rs and begat Mahalaleel : And Cainan lived after he begat Mahalaleel eight hund
# years : and he died . And Mahalaleel lived sixty and five years , and begat Jar
# s , and begat Jared : And Mahalaleel lived after he begat Jared eight hundred a
# and five yea and he died . And Jared lived an hundred sixty and two years , and
# ...

# %%
text5.concordance ('lol')
# Out:
# Displaying 25 of 822 matches:
# ast PART 24 / m boo . 26 / m and sexy lol U115 boo . JOIN PART he drew a girl w
# ope he didnt draw a penis PART ewwwww lol & a head between her legs JOIN JOIN s
# a bowl i got a blunt an a bong ...... lol JOIN well , glad it worked out my cha
# e " PART Hi U121 in ny . ACTION would lol @ U121 . . . but appearently she does
# 30 make sure u buy a nice ring for U6 lol U7 Hi U115 . ACTION isnt falling for
#  didnt ya hear !!!! PART JOIN geeshhh lol U6 PART hes deaf ppl here dont get it
# es nobody here i wanna misbeahve with lol JOIN so read it . thanks U7 .. Im hap
# ies want to chat can i talk to him !! lol U121 !!! forwards too lol JOIN ALL PE
# k to him !! lol U121 !!! forwards too lol JOIN ALL PErvs ... redirect to U121 '
#  loves ME the most i love myself JOIN lol U44 how do u know that what ? jerkett
# ng wrong ... i can see it in his eyes lol U20 = fiance Jerketts lmao wtf yah I
# ...

# %% [markdown]
# ## Similar and common_text function
#
# similar () enables us to check what other words appear in a similar range of contexts of a specific word while common_text () allows us to examine just the contexts that are shared by two or more words.

# %%
text2.similar ('lived')
# Out:
# was said had been came were is found called happened added might
# promised arrived done expected began engaged seemed continued

# %%
text2.common_contexts(["lived", "expected"])
# Out:
# who_to had_to

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text2.common_contexts (["lived", "expected"])
# Out:
# who_to had_to

# %% [markdown]
# ## Checking word location and frequency

# %%
#dispersion plot helps us locate words and how often they are used in a word text.
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %%
text5.generate ()
# Out:
# Building ngram index...
# here !! - m - canada with cam girls pm me baby U109 .. get the hell
# aint JOIN I am PART lmao U5 i hate to see me , U111 ? The Offspring -
# Come Out Swinging ... . 2 ****** Welcome to #talkcity_adults ! the
# heck is that a roaring column of flame streaks out of uniform . I dont
# know how thats facilitated . chat ? .. but hey , a / f / FL pics ,
# wanna chat pm me Whaaa ? amy have offended him ? ACTION this song is
# so good night good u
# 'here !! - m - canada with cam girls pm me baby U109 .. get the hell\naint JOIN I am PART lmao U5 i hate to see me , U111 ? The Offspring -\nCome Out Swinging ... . 2 ****** Welcome to #talkcity_adults ! the\nheck is that a roaring column of flame streaks out of uniform . I dont\nknow how thats facilitated . chat ? .. but hey , a / f / FL pics ,\nwanna chat pm me Whaaa ? amy have offended him ? ACTION this song is\nso good night good u'

# %%
# dispersion plot checking how the following words are used in the text.
text5.dispersion_plot (['lol', 'girl', 'hey', 'chat', 'good', "baby"])

# %% [markdown]
# ## Counting words in a text

# %%
len (text3) # gives us the length of both word and characters
# Out:
# 44764

# %%
set (text3) # removes duplicate words
# Out:
# {'stay',
#  'Eber',
#  'da',
#  'again',
#  'after',
#  'feebler',
#  'redeemed',
#  'Fifteen',
#  'spices',
#  'feared',
#  'conspired',
#  'daughters',
#  'that',
#  'birthright',
#  'gathering',
#  'Jordan',
#  'fema',
#  'sto',
#  'Take',
#  'plain',
#  'sh',
#  'played',
#  'broth',
#  'watered',
#  'second',
#  'felt',
#  'itself',
#  'hath',
#  'rained',
#  'Isa',
#  'Syrian',
#  'stones',
#  'Diklah',
#  'shekels',
#  'liveth',
#  'glory',
#  'poor',
#  'open',
#  'countenance',
#  'childr',
#  'emptied',
#  'Naamah',
#  'sent',
#  'dreamer',
#  'mark',
#  'findeth',
#  'meadow',
#  'Shillem',
#  'distressed',
#  'names',
#  'met',
#  'trespass',
#  'saying',
#  'half',
#  'walked',
#  'ghost',
#  'comforted',
#  'bitter',
#  'integrity',
#  'Uzal',
#  'thousand',
#  'speckled',
#  'hang',
#  'Simeon',
#  'presented',
#  'messenger',
#  'garmen',
#  'Atad',
#  'subtil',
#  'Ludim',
#  'Edar',
#  'hearkened',
#  'Bela',
#  'Naphtali',
#  'greater',
#  'Kedar',
#  'Egyptians',
# ...

# %%
print (sorted (set (text3))) # sorts the distinct words
# Out:
# ['!', "'", '(', ')', ',', ',)', '.', '.)', ':', ';', ';)', '?', '?)', 'A', 'Abel', 'Abelmizraim', 'Abidah', 'Abide', 'Abimael', 'Abimelech', 'Abr', 'Abrah', 'Abraham', 'Abram', 'Accad', 'Achbor', 'Adah', 'Adam', 'Adbeel', 'Admah', 'Adullamite', 'After', 'Aholibamah', 'Ahuzzath', 'Ajah', 'Akan', 'All', 'Allonbachuth', 'Almighty', 'Almodad', 'Also', 'Alvah', 'Alvan', 'Am', 'Amal', 'Amalek', 'Amalekites', 'Ammon', 'Amorite', 'Amorites', 'Amraphel', 'An', 'Anah', 'Anamim', 'And', 'Aner', 'Angel', 'Appoint', 'Aram', 'Aran', 'Ararat', 'Arbah', 'Ard', 'Are', 'Areli', 'Arioch', 'Arise', 'Arkite', 'Arodi', 'Arphaxad', 'Art', 'Arvadite', 'As', 'Asenath', 'Ashbel', 'Asher', 'Ashkenaz', 'Ashteroth', 'Ask', 'Asshur', 'Asshurim', 'Assyr', 'Assyria', 'At', 'Atad', 'Avith', 'Baalhanan', 'Babel', 'Bashemath', 'Be', 'Because', 'Becher', 'Bedad', 'Beeri', 'Beerlahairoi', 'Beersheba', 'Behold', 'Bela', 'Belah', 'Benam', 'Benjamin', 'Beno', 'Beor', 'Bera', 'Bered', 'Beriah', 'Bethel', 'Bethlehem', 'Bethu
# ...

# %%
len (sorted (set (text3)))
# Out:
# 2789

# %%
# lexical richness of the text
len (text3)/ len (set (text3))


# So, we can say that each word is used 16 times on average
# Out:
# 16.050197203298673

# %%
# Next, let’s focus on particular words. We can count how often a word occurs in a text,
#and compute what percentage of the text is taken up by a specific word.

print (text3.count ('smote'))

print ((text3.count('smote')/len (text3)) * 100)
# Out:
# 5
# 0.01116968992940756

# %%
#Your Turn: How many times does the word lol appear in text5? How
#much is this as a percentage of the total number of words in this text?

print (text5.count ('lol'))
print ((text5.count ('lol')/ len (text5)) * 100)
# Out:
# 704
# 1.5640968673628082

# %%
# You may want to repeat such calculations on several texts, but it is tedious to keep
#retyping the formula. Instead, you can come up with your own name for a task.

def lexical_diversity(text):
    return len(text) / len(set(text))

def percentage(word, text):
    count = text.count (word)
    total = len (text)
    return 100 * count / total

# %%
percentage ('lol', text5)
# Out:
# 1.5640968673628082

# %%
percentage ('smote', text3)
# Out:
# 0.01116968992940756

# %% [markdown]
# ## A Closer look at Text
#
# Text data in simple terms is a list of words. To work with a text data on a basic level, you need to understand operations associated with a list and a string because a text data is identified by Python as a list of word and each word is a sequence of strings.

# %%
print (sent2)
# Out:
# ['The', 'family', 'of', 'Dashwood', 'had', 'long', 'been', 'settled', 'in', 'Sussex', '.']

# %%
print (sent3)
# Out:
# ['In', 'the', 'beginning', 'God', 'created', 'the', 'heaven', 'and', 'the', 'earth', '.']

# %%
dir (sent3)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done','more', 'is', 'said', 'than', 'done']
tokens = set(saying)
tokens = sorted(tokens)

print (tokens[-2:])
print (tokens)
# Out:
# ['said', 'than']
# ['After', 'all', 'and', 'done', 'is', 'more', 'said', 'than']

# %% [markdown]
# ## Simple Statistics

# %% [markdown]
# ## Checking the Frequency Distribution

# %%
import nltk

# %%
# To check the frequency distribution, we use the FreqDist (). Note the uppercase characterization. Let's work with text 2
fdist2 = FreqDist (text2)
fdist2
# Out:
# FreqDist({',': 9397, 'to': 4063, '.': 3975, 'the': 3861, 'of': 3565, 'and': 3350, 'her': 2436, 'a': 2043, 'I': 2004, 'in': 1904, ...})

# %%
# To view each values of characters/words from the frequency distribution

for key,value in fdist2.items ():
    print (key, ':',value)
# Out:
# [ : 3
# Sense : 1
# and : 3350
# Sensibility : 1
# by : 737
# Jane : 1
# Austen : 1
# 1811 : 1
# ] : 1
# CHAPTER : 50
# 1 : 2
# The : 243
# family : 83
# of : 3565
# Dashwood : 252
# had : 969
# long : 100
# been : 440
# settled : 37
# in : 1904
# Sussex : 9
# . : 3975
# Their : 33
# estate : 19
# was : 1846
# large : 26
# , : 9397
# their : 463
# residence : 7
# at : 806
# Norland : 53
# Park : 22
# the : 3861
# centre : 2
# property : 9
# where : 84
# for : 1234
# many : 98
# generations : 1
# they : 428
# lived : 20
# so : 617
# respectable : 14
# a : 2043
# manner : 56
# as : 1179
# to : 4063
# engage : 15
# general : 55
# good : 166
# opinion : 63
# surrounding : 4
# acquaintance : 64
# late : 24
# owner : 2
# this : 372
# single : 8
# man : 121
# who : 260
# very : 492
# advanced : 9
# age : 19
# years : 49
# his : 941
# life : 58
# constant : 22
# companion : 19
# housekeeper : 5
# sister : 282
# But : 289
# her : 2436
# death : 13
# which : 592
# happened : 30
# ten : 24
# ...

# %%
# this displays only the words in the text data without their frequency distribution
fdist2.keys ()
# Out:
# dict_keys(['[', 'Sense', 'and', 'Sensibility', 'by', 'Jane', 'Austen', '1811', ']', 'CHAPTER', '1', 'The', 'family', 'of', 'Dashwood', 'had', 'long', 'been', 'settled', 'in', 'Sussex', '.', 'Their', 'estate', 'was', 'large', ',', 'their', 'residence', 'at', 'Norland', 'Park', 'the', 'centre', 'property', 'where', 'for', 'many', 'generations', 'they', 'lived', 'so', 'respectable', 'a', 'manner', 'as', 'to', 'engage', 'general', 'good', 'opinion', 'surrounding', 'acquaintance', 'late', 'owner', 'this', 'single', 'man', 'who', 'very', 'advanced', 'age', 'years', 'his', 'life', 'constant', 'companion', 'housekeeper', 'sister', 'But', 'her', 'death', 'which', 'happened', 'ten', 'before', 'own', 'produced', 'great', 'alteration', 'home', ';', 'supply', 'loss', 'he', 'invited', 'received', 'into', 'house', 'nephew', 'Mr', 'Henry', 'legal', 'inheritor', 'person', 'whom', 'intended', 'bequeath', 'it', 'In', 'society', 'niece', 'children', 'old', 'Gentleman', "'", 's', 'days', 'were', 'comfort
# ...

# %%
# Gives us the tokens with the most common frequency.
fdist2.most_common (50)
# Out:
# [(',', 9397),
#  ('to', 4063),
#  ('.', 3975),
#  ('the', 3861),
#  ('of', 3565),
#  ('and', 3350),
#  ('her', 2436),
#  ('a', 2043),
#  ('I', 2004),
#  ('in', 1904),
#  ('was', 1846),
#  ('it', 1568),
#  ('"', 1506),
#  (';', 1419),
#  ('she', 1333),
#  ('be', 1305),
#  ('that', 1297),
#  ('for', 1234),
#  ('not', 1212),
#  ('as', 1179),
#  ('you', 1037),
#  ('with', 971),
#  ('had', 969),
#  ('his', 941),
#  ('he', 895),
#  ("'", 883),
#  ('have', 807),
#  ('at', 806),
#  ('by', 737),
#  ('is', 728),
#  ('."', 721),
#  ('s', 700),
#  ('Elinor', 684),
#  ('on', 676),
#  ('all', 642),
#  ('him', 633),
#  ('so', 617),
#  ('but', 597),
#  ('which', 592),
#  ('could', 568),
#  ('Marianne', 566),
#  ('my', 551),
#  ('Mrs', 530),
#  ('from', 527),
#  ('would', 507),
#  ('very', 492),
#  ('no', 488),
#  ('their', 463),
#  ('them', 462),
#  ('--', 461)]

# %%
# if you want to access the frequency distribution of a particular word, you use this syntax. 
#You know the keys after you have checked using fdist.key ().

fdist2 ['body']
# Out:
# 52

# %%
#let's work with text 1
fdist1 = FreqDist(text1)
vocabulary1 = fdist1.keys()
vocabulary1
# Out:
# dict_keys(['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', '1851', ']', 'ETYMOLOGY', '.', '(', 'Supplied', 'a', 'Late', 'Consumptive', 'Usher', 'to', 'Grammar', 'School', ')', 'The', 'pale', '--', 'threadbare', 'in', 'coat', ',', 'heart', 'body', 'and', 'brain', ';', 'I', 'see', 'him', 'now', 'He', 'was', 'ever', 'dusting', 'his', 'old', 'lexicons', 'grammars', 'with', 'queer', 'handkerchief', 'mockingly', 'embellished', 'all', 'the', 'gay', 'flags', 'of', 'known', 'nations', 'world', 'loved', 'dust', 'it', 'somehow', 'mildly', 'reminded', 'mortality', '"', 'While', 'you', 'take', 'hand', 'school', 'others', 'teach', 'them', 'what', 'name', 'whale', '-', 'fish', 'is', 'be', 'called', 'our', 'tongue', 'leaving', 'out', 'through', 'ignorance', 'letter', 'H', 'which', 'almost', 'alone', 'maketh', 'signification', 'word', 'deliver', 'that', 'not', 'true', '."', 'HACKLUYT', 'WHALE', '...', 'Sw', 'Dan', 'HVAL', 'This', 'animal', 'named', 'from', 'roundness', 'or', 'rolling', 'for', 'HVALT
# ...

# %%
fdist1.most_common (50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %%
# This function returns the rarely used words in the text data. For text 1
print (fdist1.hapaxes ())
# Out:
# ['Herman', 'Melville', ']', 'ETYMOLOGY', 'Late', 'Consumptive', 'School', 'threadbare', 'lexicons', 'mockingly', 'flags', 'mortality', 'signification', 'HACKLUYT', 'Sw', 'HVAL', 'roundness', 'Dut', 'Ger', 'WALLEN', 'WALW', 'IAN', 'RICHARDSON', 'KETOS', 'GREEK', 'CETUS', 'LATIN', 'WHOEL', 'ANGLO', 'SAXON', 'WAL', 'HWAL', 'SWEDISH', 'ICELANDIC', 'BALEINE', 'BALLENA', 'FEGEE', 'ERROMANGOAN', 'Librarian', 'painstaking', 'burrower', 'grub', 'Vaticans', 'stalls', 'higgledy', 'piggledy', 'gospel', 'promiscuously', 'commentator', 'belongest', 'sallow', 'Pale', 'Sherry', 'loves', 'bluntly', 'Subs', 'thankless', 'Hampton', 'Court', 'hie', 'refugees', 'pampered', 'Michael', 'Raphael', 'unsplinterable', 'GENESIS', 'JOB', 'JONAH', 'punish', 'ISAIAH', 'soever', 'cometh', 'incontinently', 'perisheth', 'PLUTARCH', 'MORALS', 'breedeth', 'Whirlpooles', 'Balaene', 'arpens', 'PLINY', 'Scarcely', 'TOOKE', 'LUCIAN', 'TRUE', 'catched', 'OCTHER', 'VERBAL', 'TAKEN', 'MOUTH', 'ALFRED', '890', 'gudgeon', 'reti
# ...

# %%
print (fdist2.hapaxes ())
# Out:
# ['Sense', 'Sensibility', 'Jane', 'Austen', '1811', ']', 'generations', 'inheritor', 'bequeath', 'Gentleman', 'relish', 'devolved', 'inheriting', 'moiety', 'bequest', 'sale', 'articulation', 'economically', 'tardy', 'survived', 'including', 'legacies', 'urgency', 'prudently', 'caricature', 'warmed', 'Three', 'successively', 'funeral', 'dispute', 'decease', 'indelicacy', 'keen', 'whomsoever', 'immoveable', 'acutely', 'qualified', 'counsellor', 'joys', 'afflicted', 'strive', 'humored', 'imbibed', 'romance', 'thirteen', '2', 'installed', 'degraded', 'seasons', 'alloy', 'impoverishing', 'headed', 'stipulate', 'LET', 'diminished', 'REALLY', 'strikes', 'Fifteen', 'healthy', 'clogged', 'superannuated', 'amazing', 'restriction', 'drains', 'bind', 'inconvenient', 'enlarge', 'sixpence', 'discharging', 'presents', 'fish', 'Altogether', 'cheap', 'fulfil', 'removes', 'stock', 'belongs', 'indecorous', 'neighbourly', '3', 'remembrances', 'indefatigable', 'steadier', 'earthly', '7000L', 'repressed', 
# ...

# %% [markdown]
# ## Fine-Grained Selection of Words : Typifying a text data
#
# Next, let’s look at the long/short words of a text; perhaps these will be more characteristic and informative. We will create the for loop and set some conditions. To make it easier, we will use this syntax for list comprehension syntax.
#
# [expression with variable for (variable) in (iterator) if condition with variable]

# %%
vocab = set (text1)
long_words = [word for word in vocab if len (word) > 15]

# %%
long_words
# Out:
# ['irresistibleness',
#  'simultaneousness',
#  'comprehensiveness',
#  'characteristically',
#  'indispensableness',
#  'indiscriminately',
#  'responsibilities',
#  'undiscriminating',
#  'superstitiousness',
#  'Physiognomically',
#  'apprehensiveness',
#  'uncomfortableness',
#  'CIRCUMNAVIGATION',
#  'preternaturalness',
#  'uncompromisedness',
#  'hermaphroditical',
#  'cannibalistically',
#  'physiognomically',
#  'circumnavigation',
#  'circumnavigations',
#  'subterraneousness',
#  'uninterpenetratingly',
#  'supernaturalness',
#  'circumnavigating']

# %%
vocab_2 = set (text2)
short_words = [word for word in vocab_2 if len (word) <= 5]
print (short_words)
# Out:
# ['Mr', "?'", 'hens', 'sent', 'mark', 'hang', 'views', 'least', 'chose', 'game', 'broke', 'newer', 'cheap', 'china', 'shall', 'DEAR', 'As', 'shed', 'Seven', 'defer', 'even', 'warm', 'beef', 'moved', 'break', 'these', 'THESE', 'spasm', 'while', '-?', 'army', '&', 'shift', 'bulk', 'six', 'loss', 'Gray', ";'", 'must', 'neck', 'Smith', 'WORD', 'April', 'facts', 'pains', 'two', 'Have', 'plump', 'Do', 'HE', 'heads', 'can', 'many', 'bed', 'hasty', 'scene', '35', ',"--', 'LESS', 'blank', 'calls', 'sweep', 'harm', 'Wait', 'hints', 'wound', 'law', 'bank', 'her', 'gun', 'jokes', 'They', 'knows', 'learn', 'sign', 'sleep', 'acts', '6', 'copy', 'Mamma', 'James', 'smart', 'Fifty', 'trees', 'fixed', 'exact', 'saved', 'gales', 'END', 'anew', 'given', 'Nay', '21', 'hear', 'salts', 'shops', 'woods', 'Esq', 'post', 'downs', 'maxim', 'P', 'deal', 'short', "!'", '28', 'argue', 'paid', '),', 'gout', 'piano', 'lucky', 'hall', 'blue', 'front', 'With', '--(', 'small', 'low', 'take', 'heath', 'suit', 'From', 't
# ...

# %% [markdown]
# ### What if we check the frequently occuring long or short words depending on the concept of the text?

# %%
fdist5 = FreqDist(text5)
print (sorted([w for w in set(text5) if len(w) > 7 and fdist5[w] > 7]))
# Out:
# ['#14-19teens', '#talkcity_adults', '((((((((((', '........', 'Question', 'actually', 'anything', 'computer', 'cute.-ass', 'everyone', 'football', 'innocent', 'listening', 'remember', 'seriously', 'something', 'together', 'tomorrow', 'watching']

# %%
print (sorted ([word for word in set (text2) if len (word) <= 5 and fdist2 [word] > 20]))
# Out:
# ['!', '!"', "!'", '!--', '"', '"\'', "'", '(', ')', '),', ',', ',"', ",'", ',--', '-', '--', '--"', '.', '."', ".'", '.)', '.--', ':', ':--', ';', ';--', '?', '?"', "?'", '?--', 'A', 'All', 'And', 'As', 'At', 'Aye', 'But', 'By', 'Come', 'D', 'Do', 'Don', 'For', 'From', 'God', 'Good', 'He', 'Here', 'His', 'How', 'I', 'If', 'In', 'Is', 'It', 'Let', 'Like', 'Look', 'Lord', 'Mr', 'My', 'New', 'No', 'Nor', 'Not', 'Now', 'Of', 'Oh', 'On', 'One', 'S', 'Sir', 'So', 'Some', 'St', 'Such', 'THE', 'That', 'The', 'Then', 'There', 'These', 'They', 'This', 'Thus', 'To', 'Upon', 'We', 'Well', 'What', 'When', 'Where', 'While', 'Who', 'Why', 'With', 'Yes', 'Yet', 'You', 'a', 'about', 'above', 'act', 'added', 'after', 'again', 'age', 'ago', 'air', 'alive', 'all', 'alone', 'along', 'also', 'am', 'among', 'an', 'and', 'any', 'are', 'arm', 'arms', 'art', 'as', 'aside', 'at', 'away', 'aye', 'back', 'be', 'bear', 'beat', 'bed', 'been', 'began', 'being', 'below', 'best', 'bit', 'black', 'blood', 'blow', 'blu
# ...

# %% [markdown]
# ## Functions defined for NLTK’s frequency distributions
# Example and Description
# * fdist = FreqDist(samples)- Create a frequency distribution containing the given samples
# * fdist.inc(sample)- Increment the count for this sample
# * fdist['monstrous']- Count of the number of times a given sample occurred
# * fdist.freq('monstrous')- Frequency of a given sample
# * fdist.N()- Total number of samples
# * fdist.keys()- The samples sorted in order of decreasing frequency
# * for sample in fdist - Iterate over the samples, in order of decreasing frequency
# * fdist.max()- Sample with the greatest count
# * fdist.tabulate()- Tabulate the frequency distribution
# * fdist.plot()- Graphical plot of the frequency distribution
# * fdist.plot(cumulative=True)- Cumulative plot of the frequency distribution
# * fdist1 < fdist2- Test if samples in fdist1 occur less frequently than in fdist2

# %% [markdown]
# ##  Making Decisions and Taking Control
#
# A key feature of programming is the ability of machines to make decisions on our behalf, executing instructions when certain conditions are met, or repeatedly looping through text data until some condition is satisfied. This feature is known as **control**

# %% [markdown]
# ### Conditionals
#
# Let's try numerical operators- '>', '<', '==', '!=' and its like.

# %%
print (sent7)
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov.', '29', '.']

# %%
print ([w for w in sent7 if len(w) < 4])
# Out:
# [',', '61', 'old', ',', 'the', 'as', 'a', '29', '.']

# %%
 print ([w for w in sent7 if len(w) <= 4])
# Out:
# [',', '61', 'old', ',', 'will', 'join', 'the', 'as', 'a', 'Nov.', '29', '.']

# %%
 [w for w in sent7 if len(w) == 4]
# Out:
# ['will', 'join', 'Nov.']

# %%
print ([w for w in sent7 if len(w) != 4])
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', '29', '.']

# %% [markdown]
# ###  Word comparison operators
#
# Function Meaning
# * s.startswith(t)- Test if s starts with t
#
# * s.endswith(t)- Test if s ends with t
#
# * t in s- Test if t is contained inside s
#
# * s.islower()- Test if all cased characters in s are lowercase
#
# * s.isupper()- Test if all cased characters in s are uppercase
#
# * s.isalpha()- Test if all characters in s are alphabetic
#
# * s.isalnum()- Test if all characters in s are alphanumeric
#
# * s.isdigit()- Test if all characters in s are digits
#
# * s.istitle()- Test if s is titlecased (all words in s have initial capitals)
#
# Here are some examples of these operators being used to select words from our texts: words ending with -ableness in text 1; words containing gnt in text 4; words having an initial capital in text 6; and words consisting entirely of digits in sentence 7.

# %%
sorted([w for w in set(text1) if w.endswith('ableness')])
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
 sorted([term for term in set(text4) if 'gnt' in term])
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
sorted([item for item in set(text6) if item.istitle()])
# Out:
# ['A',
#  'Aaaaaaaaah',
#  'Aaaaaaaah',
#  'Aaaaaah',
#  'Aaaah',
#  'Aaaaugh',
#  'Aaagh',
#  'Aaah',
#  'Aaauggh',
#  'Aaaugh',
#  'Aaauugh',
#  'Aagh',
#  'Aah',
#  'Aauuggghhh',
#  'Aauuugh',
#  'Aauuuuugh',
#  'Aauuuves',
#  'Action',
#  'Actually',
#  'African',
#  'Ages',
#  'Aggh',
#  'Agh',
#  'Ah',
#  'Ahh',
#  'Alice',
#  'All',
#  'Allo',
#  'Almighty',
#  'Alright',
#  'Am',
#  'Amen',
#  'An',
#  'Anarcho',
#  'And',
#  'Angnor',
#  'Anthrax',
#  'Antioch',
#  'Anybody',
#  'Anyway',
#  'Apples',
#  'Aramaic',
#  'Are',
#  'Arimathea',
#  'Armaments',
#  'Arthur',
#  'As',
#  'Ask',
#  'Assyria',
#  'At',
#  'Attila',
#  'Augh',
#  'Autumn',
#  'Auuuuuuuugh',
#  'Away',
#  'Ay',
#  'Ayy',
#  'B',
#  'Back',
#  'Bad',
#  'Badon',
#  'Battle',
#  'Be',
#  'Beast',
#  'Bedevere',
#  'Bedwere',
#  'Behold',
#  'Between',
#  'Beyond',
#  'Black',
#  'Bloody',
#  'Blue',
#  'Bon',
#  'Bones',
#  'Book',
#  'Bors',
#  'Brave',
#  'Bravely',
#  'Bravest',
#  'Bread',
# ...

# %%
sorted([item for item in set(sent7) if item.isdigit()])
# Out:
# ['29', '61']

# %%
#what will these do: decipher
sorted([w for w in set(text7) if '-' in w and 'index' in w])
sorted([wd for wd in set(text3) if wd.istitle() and len(wd) > 10])
sorted([w for w in set(sent7) if not w.islower()])
sorted([t for t in set(text2) if 'cie' in t or 'cei' in t])

# %%
print ('Words in text 7 that contains - and index', '\n', sorted([w for w in set(text7) if '-' in w and 'index' in w]), '\n')
print ('Words in text 3 that is 10 characters long and starts with a captal letter', '\n', sorted([wd for wd in set(text3) if wd.istitle() and len(wd) > 10]), '\n')
print ('Words in sentence 7 that is in capital letters', '\n', sorted([w for w in set(sent7) if not w.islower()]), '\n')
print ('words that either contains "cie" or "cei"', '\n', sorted([t for t in set(text2) if 'cie' in t or 'cei' in t]))
# Out:
# Words in text 7 that contains - and index
#  ['Stock-index', 'index-arbitrage', 'index-fund', 'index-options', 'index-related', 'stock-index']
#
# Words in text 3 that is 10 characters long and starts with a captal letter
#  ['Abelmizraim', 'Allonbachuth', 'Beerlahairoi', 'Canaanitish', 'Chedorlaomer', 'Girgashites', 'Hazarmaveth', 'Hazezontamar', 'Ishmeelites', 'Jegarsahadutha', 'Jehovahjireh', 'Kirjatharba', 'Melchizedek', 'Mesopotamia', 'Peradventure', 'Philistines', 'Zaphnathpaaneah']
#
# Words in sentence 7 that is in capital letters
#  [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken']
#
# words that either contains "cie" or "cei"
# ...

# %% [markdown]
# ## Nested conditionals: combining "for", statements, "if" statements.....

# %%
 word = 'cat'
if len(word) < 5:
    print ('word length is less than 5')
# Out:
# word length is less than 5

# %%
if len(word) >= 5:
    print ('word length is greater than or equal to 5')
# This did not print out the statements because the condition 'word >= 5' is not met.

# %%
for word in ['Call', 'me', 'Ishmael', '.']:
    print (word)
# Out:
# Call
# me
# Ishmael
# .

# %%
# combining the if and for statements
sent1 = ['Call', 'me', 'Ishmael', '.']
for w in sent1:
    if w.endswith('l'):
        print (w)
# Out:
# Call
# Ishmael

# %%
#combining if, for, elif,else statements.
for token in sent1:
    if token.islower():
        print (token, 'is a lowercase word')
    elif token.istitle():
        print (token, 'is a titlecase word')
    else:
        print (token, 'is punctuation')
# Out:
# Call is a titlecase word
# me is a lowercase word
# Ishmael is a titlecase word
# . is punctuation

# %%
tricky = sorted([w for w in set(text2) if 'cie' in w or 'cei' in w])

for word in tricky:
    print (word,)
# Out:
# ancient
# ceiling
# conceit
# conceited
# conceive
# conscience
# conscientious
# conscientiously
# deceitful
# deceive
# deceived
# deceiving
# deficiencies
# deficiency
# deficient
# delicacies
# excellencies
# fancied
# insufficiency
# insufficient
# legacies
# perceive
# perceived
# perceiving
# prescience
# prophecies
# receipt
# receive
# received
# receiving
# society
# species
# sufficient
# sufficiently
# undeceive
# undeceiving

# %% [markdown]
# # CASE STUDY

# %%
import urllib.request 

url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = urllib.request.urlopen(url).read()

# %%
type (html)
# Out:
# bytes

# %%
print (html)
# Out:
# b'<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">\r\n<html>\r\n<head>\r\n<title>BBC NEWS | Health | Blondes \'to die out in 200 years\'</title>\r\n<meta name="keywords" content="BBC, News, BBC News, news online, world, uk, international, foreign, british, online, service">\r\n<meta name="OriginalPublicationDate" content="2002/09/27 11:51:55">\r\n<meta name="UKFS_URL" content="/1/hi/health/2284783.stm">\r\n<meta name="IFS_URL" content="/2/hi/health/2284783.stm">\r\n<meta name="HTTP-EQUIV" content="text/html;charset=iso-8859-1">\r\n<meta name="Headline" content="Blondes \'to die out in 200 years\'">\r\n<meta name="Section" content="Health">\r\n<meta name="Description" content="Natural blondes are an endangered species and will die out by 2202, a study suggests.">\r\n<!-- GENMaps-->\r\n<map name="banner">\r\n<area alt="BBC NEWS" coords="7,9,167,32" href="http://news.bbc.co.uk/1/hi.html" shape="RECT">\r\n</map>\r\n\r\n<script src
# ...

# %%
from bs4 import BeautifulSoup
response = urllib.request.urlopen(url)
html = response.read()
raw = BeautifulSoup(html).get_text()

# %%
clean
# Out:
# '\n\nBBC NEWS | Health | Blondes \'to die out in 200 years\'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNEWS\n\xa0\xa0SPORT\n\xa0\xa0WEATHER\n\xa0\xa0WORLD SERVICE\n\n\xa0\xa0A-Z INDEX\xa0\n\n\xa0\xa0SEARCH\xa0\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n    \xa0You are in:\xa0Health \xa0\r\n    \r\n    \r\n\n\n\n\n\n\n\n\n\n\n\nNews Front Page\n\n\n\n\n\nAfrica\n\n\nAmericas\n\n\nAsia-Pacific\n\n\nEurope\n\n\nMiddle East\n\n\nSouth Asia\n\n\nUK\n\n\nBusiness\n\n\nEntertainment\n\n\nScience/Nature\n\n\nTechnology\n\n\nHealth\n\n\nMedical notes\n\n\n-------------\n\n\nTalking Point\n\n\n-------------\n\n\nCountry Profiles\n\n\nIn Depth\n\n\n-------------\n\n\nProgrammes\n\n\n-------------\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSERVICES\r\n\n\n\n\n\n\n\nDaily E-mail\r\n\n\n\n\n\n\n\nNews Ticker\r\n\n\n\n\n\n\n\nMobile/PDAs\r\n\n\n\n\n\n\n-------------\r\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nText Only\n\
# ...

# %%
tokens = nltk.word_tokenize(raw)
tokens
# Out:
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'to",
#  'die',
#  'out',
#  'in',
#  '200',
#  "years'",
#  'NEWS',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'A-Z',
#  'INDEX',
#  'SEARCH',
#  'You',
#  'are',
#  'in',
#  ':',
#  'Health',
#  'News',
#  'Front',
#  'Page',
#  'Africa',
#  'Americas',
#  'Asia-Pacific',
#  'Europe',
#  'Middle',
#  'East',
#  'South',
#  'Asia',
#  'UK',
#  'Business',
#  'Entertainment',
#  'Science/Nature',
#  'Technology',
#  'Health',
#  'Medical',
#  'notes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Talking',
#  'Point',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Country',
#  'Profiles',
#  'In',
#  'Depth',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Programmes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'SERVICES',
#  'Daily',
#  'E-mail',
#  'News',
#  'Ticker',
#  'Mobile/PDAs',
#  '--',
#  '--',
#  '--',
#  '--',
# ...

# %%
words = [w for w in tokens if w.isalpha() and len(w) > 4]

# %%
words
# Out:
# ['Health',
#  'Blondes',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'INDEX',
#  'SEARCH',
#  'Health',
#  'Front',
#  'Africa',
#  'Americas',
#  'Europe',
#  'Middle',
#  'South',
#  'Business',
#  'Entertainment',
#  'Technology',
#  'Health',
#  'Medical',
#  'notes',
#  'Talking',
#  'Point',
#  'Country',
#  'Profiles',
#  'Depth',
#  'Programmes',
#  'SERVICES',
#  'Daily',
#  'Ticker',
#  'Feedback',
#  'EDITIONS',
#  'Change',
#  'Friday',
#  'September',
#  'Blondes',
#  'Scientists',
#  'believe',
#  'blondes',
#  'Finland',
#  'natural',
#  'blondes',
#  'within',
#  'years',
#  'scientists',
#  'believe',
#  'study',
#  'experts',
#  'Germany',
#  'suggests',
#  'people',
#  'blonde',
#  'endangered',
#  'species',
#  'become',
#  'extinct',
#  'Researchers',
#  'predict',
#  'truly',
#  'natural',
#  'blonde',
#  'Finland',
#  'country',
#  'highest',
#  'proportion',
#  'blondes',
#  'frequency',
#  'blondes',
#  'disappear',
#  'Jonathan',
#  'University',
# ...

# %%
text = nltk.Text(words)
